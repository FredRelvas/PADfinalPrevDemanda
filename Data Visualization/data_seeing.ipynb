# %%
import pandas as pd

file_path = 'DADOS_BRUTOS_INPUTADO.csv'

try:
    df = pd.read_csv(file_path)

    print("--- 5 Primeiras Linhas ---")
    print(df.head())
    print("\n" + "="*50 + "\n")

    print("--- Informações dos Dados ---")
    df.info()
    print("\n" + "="*50 + "\n")

    print("--- Estatísticas Descritivas ---")
    print(df.describe())
    print("\n" + "="*50 + "\n")

    print("--- Nomes das Colunas ---")
    print(df.columns)
    print("\n" + "="*50 + "\n")

    print("--- Valores Únicos por Coluna ---")
    print(df.nunique())
    print("\n" + "="*50 + "\n")

except FileNotFoundError:
    print(f"Erro: O arquivo '{file_path}' não foi encontrado.")
except Exception as e:
    print(f"Ocorreu um erro: {e}")
# Out:
# --- First 5 Rows ---
#                                                     id_subsistema;nom_subsistema;din_instante;val_cargaenergiamwmed
# N;Norte;01/01/2000 00:00:00;2.243                                                            51250000
# NE;Nordeste;01/01/2000 00:00:00;4.646                                                        37083333
# S;Sul;01/01/2000 00:00:00;4.800                                                              65000000
# SE;Sudeste/Centro-Oeste;01/01/2000 00:00:00;19.045                                           99583333
# N;Norte;02/01/2000 00:00:00;2.259                                                            80833333
#
# ==================================================
#
# --- Data Info ---
# <class 'pandas.core.frame.DataFrame'>
# Index: 37181 entries, N;Norte;01/01/2000 00:00:00;2.243 to SE;Sudeste/Centro-Oeste;12-06-25 00:00:00;41.192
# Data columns (total 1 columns):
#  #   Column                                                           Non-Null Count  Dtype
# ---  ------                                                           --------------  -----
#  0   id_subsistema;nom_subsistema;din_instante;val_cargaenergiamwmed  37181 non-null  int64
# dtypes: int64(1)
# memory usage: 581.0+ KB
#
# ==================================================
#
# --- Descriptive Statistics ---
#        id_subsistema;nom_subsistema;din_instante;val_cargaenergiamwmed
# count                                       3.718100e+04
# mean                                        5.009796e+07
# std                                         2.885312e+07
# min                                         0.000000e+00
# 25%                                         2.500000e+07
# 50%                                         5.020833e+07
# 75%                                         7.511667e+07
# max                                         9.998750e+07
#
# ==================================================
#
# --- Column Names ---
# Index(['id_subsistema;nom_subsistema;din_instante;val_cargaenergiamwmed'], dtype='object')
#
# ==================================================
#
# --- Unique Values per Column ---
# id_subsistema;nom_subsistema;din_instante;val_cargaenergiamwmed    18361
# dtype: int64
#
# ==================================================
